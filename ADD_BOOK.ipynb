# %% [markdown]
# <a href="https://colab.research.google.com/github/mikazz/TripAdvisor/blob/master/ADD_BOOK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Wyciąganie ciekawych informacji z plików źródłowych. Parsowanie plików *.dat

# %% [markdown]
# ## Przykładowy plik  *.dat

# %% [markdown]
# ```
# <Overall Rating>4.5
# <Avg. Price>$124
# <URL>Chelsea Lodge
#
# <Author>NYGuest
# <Content>Torturous Stay -> learned the hard way We were upgraded without our knowledge and then charged for it. We stayed for three days. Our room was a dungeon below street level. The walls are paper thin, and there was quite a bit of noise from other guests. The room was not clean. There were spots of what appeared to be blood above the sink in the bathroom, and clearly they have never cleaned the walls or doorknobs in the bedroom. The sheets and towels are threadbare - literally - with holes in them. There were brown stain streaks on both sets of sheets we infested. There was no temperature control in the room. We were at the mercy of the guests above us. The first two nights we froze and the last night we roasted. For some reason they decided to not clean our room on the second day. I can only surmise as a cost saving measure.We are staying in New York for 9 nights and if they didn't have a 72 hour no-cancellation policy we would have left after the first night. We are now staying in a much more comfortable and squeaky clean hotel that is $80 less a night (booked through hotline dot com)The hotel has no service whatsoever. It's basically a motel with no parking. To me that means 1 star. We are feeling ripped off at this point. 190/night for a room in a converted basement is absurd in any city. For the life of me I cannot explain our experience. I read through previous reviews carefully and we expected some charm here. Alas this was not the case. I am left with the suspicion that the hotel has spammed this board with a large number of their own reviews. I would unequivocally not recommend this establishment. There are many comfortable and clean hotels in New York that have a number of guest services and can be had for less money if you merely take the time to shop on the internet at any of a number of web sites.
# <Date>Jan 4, 2009
# <img src="http://cdn.tripadvisor.com/img2/new.gif" alt="New"/>
# <No. Reader>3
# <No. Helpful>1
# <Overall>1
# <Value>1
# <Rooms>1
# <Location>3
# <Cleanliness>1
# <Check in / front desk>2
# <Service>-1
# <Business service>3
# ```

# %% [markdown]
# ## Parsowanie do czytelnej formy

# %%
import glob
import re

PATH = "reviews_folder\*.dat"


files = glob.glob(PATH)
for name in files:
    try:
        with open(name) as file:
            file_name = name.split('\\')
            file_name = file_name[1]
            name = file_name.split(".")
            name = name[0]
            
            content = file.read()
            
            rating_list = re.findall('<Overall Rating>(.*)', content)
            price_list = re.findall('<Avg. Price>(.*)', content)
            url_list = re.findall('<URL>(.*)', content)
            comment_number = len(re.findall('<Author>(.*)', content))

            fmt = '{};{};{};{};{}'
            for i, (rating, price, url) in enumerate(zip(rating_list, price_list, url_list)):
                print(fmt.format(name, rating, price, url, comment_number))

            
        
    except IOError as e:
        print(e)

# %% [markdown]
# ```
# Filename: hotel_72572.txt
# Overall Rating:4
# Average Price: 173 USD
# Hotel Name: Best_Western_Pioneer_Square_Hotel-Seattle_Washington
# Total Comments Number: 81
#
# Filename: hotel_72579.txt
# Overall Rating:3
# Average Price: 147 USD
# Hotel Name: Best_Western_Loyal_Inn-Seattle_Washington
# Total Comments Number: 38
#
# Filename: hotel_72586.txt
# Overall Rating:3.5
# Average Price: 172 USD
# Hotel Name: Best_Western_Executive_Inn-Seattle_Washington
# Total Comments Number: 57
#
# Filename: hotel_73718.txt
# Overall Rating:3.5
# Average Price: 162 USD
# Hotel Name: Best_Western_Central_Phoenix_Inn_Suites-Phoenix_Arizona
# Total Comments Number: 28
#
# Filename: hotel_73727.txt
# Overall Rating:3
# Average Price: 137 USD
# Hotel Name: Grace_Inn_at_Ahwatukee-Phoenix_Arizona
# Total Comments Number: 23
#
# Filename: hotel_73739.txt
# Overall Rating:3.5
# Average Price: 159 USD
# Hotel Name: Best_Western_InnSuites_Hotels_Phoenix-Phoenix_Arizona
# Total Comments Number: 23
#
# Filename: hotel_73757.txt
# Overall Rating:3.5
# Average Price: 260 USD
# Hotel Name: Wyndham_Phoenix-Phoenix_Arizona
# Total Comments Number: 55
#
# Filename: hotel_73787.txt
# Overall Rating:3
# Average Price: 185 USD
# Hotel Name: Embassy_Suites_Phoenix_Airport-Phoenix_Arizona
# Total Comments Number: 46
#
# Filename: hotel_73799.txt
# Overall Rating:3
# Average Price: 202 USD
# Hotel Name: Embassy_Suites_Hotel_Phoenix_North-Phoenix_Arizona
# Total Comments Number: 44
#
# Filename: hotel_73821.txt
# Overall Rating:4
# Average Price: 242 USD
# Hotel Name: Hilton_Phoenix_Airport-Phoenix_Arizona
# Total Comments Number: 46
#
# Filename: hotel_73855.txt
# Overall Rating:3.5
# Average Price: 297 USD
# Hotel Name: Hyatt_Regency_Phoenix-Phoenix_Arizona
# Total Comments Number: 75
#
# Filename: hotel_73923.txt
# Overall Rating:4
# Average Price: 185 USD
# Hotel Name: Radisson_Hotel_Phoenix_Airport_Southbank-Phoenix_Arizona
# Total Comments Number: 35
#
# Filename: hotel_73943.txt
# Overall Rating:4.5
# Average Price: 490 USD
# Hotel Name: Royal_Palms_Resort_and_Spa-Phoenix_Arizona
# Total Comments Number: 138
#
# Filename: hotel_73947.txt
# Overall Rating:3
# Average Price: 206 USD
# Hotel Name: Sheraton_Crescent_Hotel-Phoenix_Arizona
# Total Comments Number: 31
#
# Filename: hotel_73950.txt
# Overall Rating:3.5
# Average Price: 122 USD
# Hotel Name: Sleep_Inn_Airport-Phoenix_Arizona
# Total Comments Number: 27
#
# Filename: hotel_73957.txt
# Overall Rating:3.5
# Average Price: 184 USD
# Hotel Name: Pointe_Hilton_Squaw_Peak_Resort-Phoenix_Arizona
# Total Comments Number: 270
#
# Filename: hotel_73985.txt
# Overall Rating:2
# Average Price: 68 USD
# Hotel Name: Travelodge_Phoenix_32nd_St-Phoenix_Arizona
# Total Comments Number: 13
#
# Filename: hotel_74051.txt
# Overall Rating:3
# Average Price: 95 USD
# Hotel Name: Edward_II_Inn_and_Suites-San_Francisco_California
# Total Comments Number: 29
#
# Filename: hotel_74583.txt
# Overall Rating:4.5
# Average Price: 193 USD
# Hotel Name: Fairfield_Inn_Phoenix_Airport-Phoenix_Arizona
# Total Comments Number: 25
#
# Filename: hotel_74626.txt
# Overall Rating:4
# Average Price: 280 USD
# Hotel Name: Legacy_Golf_Resort-Phoenix_Arizona
# Total Comments Number: 96
#
# Filename: hotel_75662.txt
# Overall Rating:4.5
# Average Price: 158 USD
# Hotel Name: Holiday_Inn_Express_Phoenix_Airport_University_Drive-Phoenix_Arizona
# Total Comments Number: 40
#
# Filename: hotel_76061.txt
# Overall Rating:3.5
# Average Price: 231 USD
# Hotel Name: Crowne_Plaza_Beverly_Hills-Los_Angeles_California
# Total Comments Number: 155
#
# Filename: hotel_76083.txt
# Overall Rating:4
# Average Price: 300 USD
# Hotel Name: Sofitel_Los_Angeles-Los_Angeles_California
# Total Comments Number: 100
#
# Filename: hotel_76442.txt
# Overall Rating:4
# Average Price: 379 USD
# Hotel Name: Hyatt_Regency_Century_Plaza-Los_Angeles_California
# Total Comments Number: 196
#
# Filename: hotel_77055.txt
# Overall Rating:2.5
# Average Price: 160 USD
# Hotel Name: Hotel_Royal-New_Orleans_Louisiana
# Total Comments Number: 88
#
# Filename: hotel_77264.txt
# Overall Rating:3.5
# Average Price: 236 USD
# Hotel Name: Hollywood_Heights_Hotel-Los_Angeles_California
# Total Comments Number: 164
#
# Filename: hotel_77270.txt
# Overall Rating:4
# Average Price: 128 USD
# Hotel Name: Hollywood_Orchid_Suites-Los_Angeles_California
# Total Comments Number: 185
#
# Filename: hotel_77274.txt
# Overall Rating:3.5
# Average Price: 349 USD
# Hotel Name: Hollywood_Roosevelt_Hotel-Los_Angeles_California
# Total Comments Number: 338
#
# Filename: hotel_77629.txt
# Overall Rating:3.5
# Average Price: 172 USD
# Hotel Name: Best_Western_Terrace_Inn-Boston_Massachusetts
# Total Comments Number: 35
#
# Filename: hotel_77638.txt
# Overall Rating:3.5
# Average Price: 265 USD
# Hotel Name: Best_Western_Boston_The_Inn_at_Longwood_Medical-Boston_Massachusetts
# Total Comments Number: 59
#
# Filename: hotel_77700.txt
# Overall Rating:3.5
# Average Price: 396 USD
# Hotel Name: W_Los_Angeles_Westwood-Los_Angeles_California
# Total Comments Number: 126
#
# Filename: hotel_77714.txt
# Overall Rating:3.5
# Average Price: 218 USD
# Hotel Name: Kyoto_Grand_Hotel_and_Gardens-Los_Angeles_California
# Total Comments Number: 80
#
# Filename: hotel_77775.txt
# Overall Rating:4.5
# Average Price: 309 USD
# Hotel Name: Hotel_Palomar_Los_Angeles_Westwood_a_Kimpton_Hotel-Los_Angeles_California
# Total Comments Number: 92
#
# Filename: hotel_77804.txt
# Overall Rating:4.5
# Average Price: 301 USD
# Hotel Name: Omni_Los_Angeles_at_California_Plaza-Los_Angeles_California
# Total Comments Number: 262
#
# Filename: hotel_77827.txt
# Overall Rating:3.5
# Average Price: 267 USD
# Hotel Name: Luxe_Hotel_Sunset_Boulevard-Los_Angeles_California
# Total Comments Number: 72
#
# Filename: hotel_77866.txt
# Overall Rating:3.5
# Average Price: 264 USD
# Hotel Name: Millennium_Biltmore_Hotel_Los_Angeles-Los_Angeles_California
# Total Comments Number: 286
#
# Filename: hotel_77917.txt
# Overall Rating:3.5
# Average Price: 214 USD
# Hotel Name: Embassy_Suites_Hotel_LAX_North-Los_Angeles_California
# Total Comments Number: 87
#
# Filename: hotel_77944.txt
# Overall Rating:4
# Average Price: 234 USD
# Hotel Name: Renaissance_Montura_Los_Angeles-Los_Angeles_California
# Total Comments Number: 194
#
# Filename: hotel_78046.txt
# Overall Rating:3.5
# Average Price: 209 USD
# Hotel Name: Sheraton_Gateway_Los_Angeles_Hotel-Los_Angeles_California
# Total Comments Number: 233
#
# Filename: hotel_78682.txt
# Overall Rating:4
# Average Price: 204 USD
# Hotel Name: Beverly_Garland_s_Holiday_Inn-Los_Angeles_California
# Total Comments Number: 150
#
# Filename: hotel_78688.txt
# Overall Rating:3.5
# Average Price: 208 USD
# Hotel Name: Sportsmen_s_Lodge_Hotel-Los_Angeles_California
# Total Comments Number: 70
#
# Filename: hotel_78694.txt
# Overall Rating:4
# Average Price: 233 USD
# Hotel Name: Hilton_Los_Angeles_Universal_City-Los_Angeles_California
# Total Comments Number: 259
#
# Filename: hotel_79500.txt
# Overall Rating:2.5
# Average Price: 199 USD
# Hotel Name: Best_Western_The_Plaza_Hotel-Honolulu_Oahu_Hawaii
# Total Comments Number: 55
#
# Filename: hotel_80083.txt
# Overall Rating:4.5
# Average Price: 124 USD
# Hotel Name: Chelsea Lodge
# Total Comments Number: 223
#
# Filename: hotel_80087.txt
# Overall Rating:4.5
# Average Price: 344 USD
# Hotel Name: NYC
# Total Comments Number: 146
#
# Filename: hotel_80275.txt
# Overall Rating:3.5
# Average Price: 188 USD
# Hotel Name: Holiday_Inn_Port_of_Miami_Downtown-Miami_Florida
# Total Comments Number: 147
#
# Filename: hotel_80747.txt
# Overall Rating:4
# Average Price: 436 USD
# Hotel Name: Renaissance_Stanford_Court-San_Francisco_California
# Total Comments Number: 225
#
# Filename: hotel_80756.txt
# Overall Rating:3.5
# Average Price: 113 USD
# Hotel Name: Adante_Hotel-San_Francisco_California
# Total Comments Number: 157
#
# Filename: hotel_80771.txt
# Overall Rating:3
# Average Price: 174 USD
# Hotel Name: The_Herbert_Hotel-San_Francisco_California
# Total Comments Number: 52
#
# Filename: hotel_80774.txt
# Overall Rating:4
# Average Price: 148 USD
# Hotel Name: The_Stratford-San_Francisco_California
# Total Comments Number: 161
#
# Filename: hotel_80780.txt
# Overall Rating:4
# Average Price: 258 USD
# Hotel Name: Best_Western_Tuscan_Inn_Fisherman_s_Wharf_a_Kimpton_Hotel-San_Francisco_California
# Total Comments Number: 433
#
# Filename: hotel_80784.txt
# Overall Rating:3
# Average Price: 204 USD
# Hotel Name: Cathedral_Hill_Hotel-San_Francisco_California
# Total Comments Number: 235
#
# Filename: hotel_80786.txt
# Overall Rating:3.5
# Average Price: 194 USD
# Hotel Name: King_George_Hotel-San_Francisco_California
# Total Comments Number: 183
#
# Filename: hotel_80788.txt
# Overall Rating:3
# Average Price: 115 USD
# Hotel Name: Monarch_Hotel-San_Francisco_California
# Total Comments Number: 95
#
# Filename: hotel_80793.txt
# Overall Rating:4
# Average Price: 339 USD
# Hotel Name: Nikko_Hotel_San_Francisco-San_Francisco_California
# Total Comments Number: 302
#
# Filename: hotel_80797.txt
# Overall Rating:4
# Average Price: 427 USD
# Hotel Name: Hotel_Palomar_San_Francisco_a_Kimpton_Hotel-San_Francisco_California
# Total Comments Number: 240
#
# Filename: hotel_80799.txt
# Overall Rating:2.5
# Average Price: 130 USD
# Hotel Name: Renoir_Hotel-San_Francisco_California
# Total Comments Number: 177
#
# Filename: hotel_80802.txt
# Overall Rating:4
# Average Price: 326 USD
# Hotel Name: Serrano_Hotel_a_Kimpton_Hotel-San_Francisco_California
# Total Comments Number: 248
#
# Filename: hotel_80808.txt
# Overall Rating:4
# Average Price: 141 USD
# Hotel Name: Beresford_Arms-San_Francisco_California
# Total Comments Number: 145
#
# Filename: hotel_80836.txt
# Overall Rating:3.5
# Average Price: 111 USD
# Hotel Name: Hotel_Beresford-San_Francisco_California
# Total Comments Number: 72
#
# Filename: hotel_80864.txt
# Overall Rating:4
# Average Price: 179 USD
# Hotel Name: Best_Western_Carriage_Inn-San_Francisco_California
# Total Comments Number: 76
#
# Filename: hotel_80879.txt
# Overall Rating:3.5
# Average Price: 209 USD
# Hotel Name: Best_Western_Civic_Center_Motor_Inn-San_Francisco_California
# Total Comments Number: 58
#
# Filename: hotel_80912.txt
# Overall Rating:3.5
# Average Price: 174 USD
# Hotel Name: Sheraton_Gateway_San_Francisco_Airport_Hotel-San_Francisco_California
# Total Comments Number: 121
#
# Filename: hotel_80917.txt
# Overall Rating:4
# Average Price: 200 USD
# Hotel Name: Best_Western_Hotel_Tomo-San_Francisco_California
# Total Comments Number: 90
#
# Filename: hotel_80920.txt
# Overall Rating:3.5
# Average Price: 163 USD
# Hotel Name: Hotel_Bijou-San_Francisco_California
# Total Comments Number: 168
#
# Filename: hotel_80925.txt
# Overall Rating:4.5
# Average Price: 160 USD
# Hotel Name: Hotel_Carlton_San_Francisco-San_Francisco_California
# Total Comments Number: 105
#
# Filename: hotel_80930.txt
# Overall Rating:3.5
# Average Price: 157 USD
# Hotel Name: Comfort_Inn_by_the_Bay-San_Francisco_California
# Total Comments Number: 202
#
# Filename: hotel_80937.txt
# Overall Rating:3
# Average Price: 172 USD
# Hotel Name: Cornell_Hotel_de_France-San_Francisco_California
# Total Comments Number: 45
#
# Filename: hotel_80983.txt
# Overall Rating:4.5
# Average Price: 275 USD
# Hotel Name: Hotel_Drisco-San_Francisco_California
# Total Comments Number: 227
#
# Filename: hotel_80987.txt
# Overall Rating:2
# Average Price: 71 USD
# Hotel Name: Presidio_Inn-San_Francisco_California
# Total Comments Number: 25
#
# Filename: hotel_80990.txt
# Overall Rating:4
# Average Price: 391 USD
# Hotel Name: Galleria_Park-San_Francisco_California
# Total Comments Number: 139
#
# Filename: hotel_80999.txt
# Overall Rating:3.5
# Average Price: 348 USD
# Hotel Name: Grand_Hyatt_San_Francisco-San_Francisco_California
# Total Comments Number: 286
#
# Filename: hotel_81004.txt
# Overall Rating:2.5
# Average Price: 93 USD
# Hotel Name: Grant_Plaza_Hotel-San_Francisco_California
# Total Comments Number: 132
#
# Filename: hotel_81019.txt
# Overall Rating:4
# Average Price: 227 USD
# Hotel Name: Handlery_Union_Square_Hotel-San_Francisco_California
# Total Comments Number: 367
#
# Filename: hotel_81022.txt
# Overall Rating:4
# Average Price: 269 USD
# Hotel Name: Harbor_Court_Hotel_a_Kimpton_Hotel-San_Francisco_California
# Total Comments Number: 137
#
# Filename: hotel_81035.txt
# Overall Rating:2.5
# Average Price: 156 USD
# Hotel Name: Holiday_Inn_San_Francisco_Civic_Center-San_Francisco_California
# Total Comments Number: 98
#
# Filename: hotel_81038.txt
# Overall Rating:4
# Average Price: 236 USD
# Hotel Name: Hilton_San_Francisco_Financial_District-San_Francisco_California
# Total Comments Number: 262
#
# Filename: hotel_81042.txt
# Overall Rating:3.5
# Average Price: 165 USD
# Hotel Name: Holiday_Inn_San_Francisco_Fishermans_Wharf-San_Francisco_California
# Total Comments Number: 254
#
# Filename: hotel_81049.txt
# Overall Rating:3.5
# Average Price: 173 USD
# Hotel Name: Holiday_Inn_San_Francisco_Golden_Gateway-San_Francisco_California
# Total Comments Number: 177
#
# Filename: hotel_81082.txt
# Overall Rating:3.5
# Average Price: 285 USD
# Hotel Name: Courtyard_by_Marriott_Fisherman_s_Wharf-San_Francisco_California
# Total Comments Number: 62
#
# Filename: hotel_81087.txt
# Overall Rating:4
# Average Price: 269 USD
# Hotel Name: Hyatt_at_Fisherman_s_Wharf-San_Francisco_California
# Total Comments Number: 199
#
# Filename: hotel_81103.txt
# Overall Rating:4
# Average Price: 314 USD
# Hotel Name: Hyatt_Regency_San_Francisco-San_Francisco_California
# Total Comments Number: 246
#
# Filename: hotel_81110.txt
# Overall Rating:4
# Average Price: 400 USD
# Hotel Name: Campton_Place_Hotel-San_Francisco_California
# Total Comments Number: 76
#
# Filename: hotel_81114.txt
# Overall Rating:4
# Average Price: 212 USD
# Hotel Name: Laurel_Inn-San_Francisco_California
# Total Comments Number: 49
#
# Filename: hotel_81126.txt
# Overall Rating:4.5
# Average Price: 493 USD
# Hotel Name: Mandarin_Oriental-San_Francisco_California
# Total Comments Number: 151
#
# Filename: hotel_81141.txt
# Overall Rating:4
# Average Price: 287 USD
# Hotel Name: Marriott_San_Francisco_Fisherman_s_Wharf-San_Francisco_California
# Total Comments Number: 146
#
# Filename: hotel_81165.txt
# Overall Rating:4
# Average Price: 369 USD
# Hotel Name: Hotel_Abri-San_Francisco_California
# Total Comments Number: 91
#
# Filename: hotel_81169.txt
# Overall Rating:4
# Average Price: 141 USD
# Hotel Name: The_Mosser-San_Francisco_California
# Total Comments Number: 346
#
# Filename: hotel_81170.txt
# Overall Rating:3.5
# Average Price: 248 USD
# Hotel Name: Marina_Pacific_Hotel_Suites-Los_Angeles_California
# Total Comments Number: 57
#
# Filename: hotel_81177.txt
# Overall Rating:4
# Average Price: 265 USD
# Hotel Name: Nob_Hill_Motor_Inn-San_Francisco_California
# Total Comments Number: 361
#
# Filename: hotel_81192.txt
# Overall Rating:4
# Average Price: 278 USD
# Hotel Name: Parc_55_Hotel-San_Francisco_California
# Total Comments Number: 500
#
# Filename: hotel_81204.txt
# Overall Rating:4.5
# Average Price: 379 USD
# Hotel Name: Le_Meridien_San_Francisco-San_Francisco_California
# Total Comments Number: 201
#
# Filename: hotel_81209.txt
# Overall Rating:4
# Average Price: 170 USD
# Hotel Name: Phoenix_Hotel-San_Francisco_California
# Total Comments Number: 131
#
# Filename: hotel_81215.txt
# Overall Rating:4
# Average Price: 385 USD
# Hotel Name: Prescott_Hotel_a_Kimpton_Hotel-San_Francisco_California
# Total Comments Number: 171
#
# Filename: hotel_81237.txt
# Overall Rating:3.5
# Average Price: 235 USD
# Hotel Name: Hilton_San_Francisco_Fisherman_s_Wharf-San_Francisco_California
# Total Comments Number: 100
#
# Filename: hotel_81241.txt
# Overall Rating:3.5
# Average Price: 189 USD
# Hotel Name: Hotel_Whitcomb-San_Francisco_California
# Total Comments Number: 282
#
# Filename: hotel_81246.txt
# Overall Rating:2
# Average Price: 116 USD
# Hotel Name: Ramada_Limited_Downtown-San_Francisco_California
# Total Comments Number: 40
#
# Filename: hotel_81249.txt
# Overall Rating:4
# Average Price: 82 USD
# Hotel Name: Redwood_Inn-San_Francisco_California
# Total Comments Number: 101
#
# Filename: hotel_81251.txt
# Overall Rating:3.5
# Average Price: 179 USD
# Hotel Name: Opal_Hotel-San_Francisco_California
# Total Comments Number: 169
#
# Filename: hotel_81315.txt
# Overall Rating:4
# Average Price: 367 USD
# Hotel Name: San_Francisco_Marriott-San_Francisco_California
# Total Comments Number: 236
# ```

# %%
import glob
import re

PATH = "reviews_folder\*.dat"


files = glob.glob(PATH)
for name in files:
    try:
        with open(name) as file:
            file_name = name.split('\\')
            file_name = file_name[1]
            name = file_name.split(".")
            name = name[0]
            
            content = file.read()
            
            rating_list = re.findall('<Overall Rating>(.*)', content)
            price_list = re.findall('<Avg. Price>(.*)', content)
            url_list = re.findall('<URL>(.*)', content)
            comment_number = len(re.findall('<Author>(.*)', content))

            #fmt_csv = '{};{};{};{};{}'
            fmt_pretty = 'Filename: {}.txt\nOverall Rating:{}\nAverage Price: {} USD\nHotel Name: {}\nTotal Comments Number: {}\n'
            for i, (rating, price, url) in enumerate(zip(rating_list, price_list, url_list)):
                try:
                    new_url = re.findall('(\d{8}-)(.*?)(.html)', url)
                    new_url = new_url[0][1]
                except:
                    new_url = url

                
                print(fmt_pretty.format(name, rating, price[1::], new_url, comment_number))

            
    except IOError as e:
        print(e)

# %% [markdown]
# ```
# hotel_81251;3.5;$179;http://www.tripadvisor.com/ShowUserReviews-g60713-d81251-r23352903-Opal_Hotel-San_Francisco_California.html;169
# hotel_81315;4;$367;http://www.tripadvisor.com/ShowUserReviews-g60713-d81315-r23333280-San_Francisco_Marriott-San_Francisco_California.html;236
# ```

# %% [markdown]
# # Parsowanie plików *.txt

# %% [markdown]
# ## Przykładowy plik *.txt z hotelami

# %% [markdown]
# ```
# <Author>RW53
# <Content>Location! Location?       view from room of nearby freeway
# <Date>Dec 26, 2008
# <Rating>3	4	3	2	4	3	-1	-1
# ```

# %% [markdown]
# ## Parsowanie do postaci:
#   komentarz \n
#   komentarz \n
#   komentarz \n

# %%
import re
import glob


content_list = []

date_lists = []
PATH = "HOTELS\*.txt"


def write_rating_to_file(rating_lists, file_name):
    for list in rating_lists:
        #print(line)

        with open(file_name, "a") as file:
            file.write(str(list[0]) + "\n")


def write_to_file(content_list, file_name):
    for line in content_list:
        with open(file_name, "a") as file:
            file.write(line + "\n")


def content_parser(content):
    for i in content:
        # Clean nasty parsing errors ( showReview(1020542, 'full'); and etc )
        i = re.sub(r'(showReview)(.*)(;)'," ", i)
        # Clean all whitespace characters (space, tab, newline, return, formfeed) too
        i = " ".join(i.split())
        # Append cleaned line
        content_list.append(i)


def rating_parser(rating):
    rating_list = []
    for i in rating:
        i = i.split("\t")
        rating_list.append(i)

    for i in rating_list:
        # remove all occurrences of whitespace (replace)
        i[:] = [x for x in i if x is not '']
        # convert all strings to ints (replace)
        i[:] = [int(x) for x in i]

    return rating_list


def main():
    files = glob.glob(PATH)
    for name in files:
        with open(name) as file:
            file_name = name.split('\\')
            file_name = file_name[1]
            print("Parsed: " + file_name)

            lines = file.read()
            # Find all text with <Content> at the beginning
            content = re.findall('<Content>(.*)', lines)
            content_parser(content)

            # Rating lists
            rating = re.findall('<Rating>(.*)', lines)
            rate = rating_parser(rating)
            #print(rate)
            write_rating_to_file(rate, "R" + file_name)
            
            # Date lists
            date_lists = re.findall('<Date>(.*)', lines)

        new_file_name = "P" + file_name
        write_to_file(content_list, new_file_name)
        global content_list
        content_list = []


    print("Done Parsing")

    
if __name__ == "__main__":
    main()
